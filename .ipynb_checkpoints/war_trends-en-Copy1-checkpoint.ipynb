# %%
from pytrends.request import TrendReq
import pytrends as pt
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import pycountry
import plotly.graph_objects as go

# %%
pytrends = TrendReq(hl='en-US', tz=360)

kw_list = ['war', 'ukraine', 'russia'] # list of keywords to get data 

pytrends.build_payload(kw_list, cat=0, timeframe='today 3-m')

# %%
#1 Interest over Time

data = pytrends.interest_over_time() 
data = data.reset_index()

# %%
data = data[(data['date'] >= '2022-02-01') & (data['date'] < '2022-04-03')]

# %%
data
# Out:
#          date  war  ukraine  russia  isPartial
# 27 2022-02-01    3        1       2      False
# 28 2022-02-02    3        1       2      False
# 29 2022-02-03    3        1       2      False
# 30 2022-02-04    3        1       2      False
# 31 2022-02-05    3        1       2      False
# ..        ...  ...      ...     ...        ...
# 83 2022-03-29    4        8       4      False
# 84 2022-03-30    4        7       3      False
# 85 2022-03-31    4        6       3      False
# 86 2022-04-01    4        6       3      False
# 87 2022-04-02    4        6       3      False
#
# [61 rows x 5 columns]

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=data['date'], y=data['ukraine'],
                    mode='lines+markers',
                    name='Ukraine'))
fig.add_trace(go.Scatter(x=data['date'], y=data['war'],
                    mode='lines+markers',
                    name='War'))
fig.add_trace(go.Scatter(x=data['date'], y=data['russia'],
                    mode='lines+markers', 
                    name='Russia', line_color='yellow'))

fig.show()
# Out:
# <div>                            <div id="784c794a-8e59-45f6-9349-2b67e5e76ded" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("784c794a-8e59-45f6-9349-2b67e5e76ded")) {                    Plotly.newPlot(                        "784c794a-8e59-45f6-9349-2b67e5e76ded",                        [{"mode":"lines+markers","name":"Ukraine","x":["2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-05T00:00:00","2022-02-06T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-12T00:00:00","2022-02-13T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-19T00:00:00","2022-02-20T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-26T00:00:00","2022-02-27T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-05T00:00:00","2022-03-06T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-12T00:00:00","2022-03-13T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-19T00:00:00","2022-03-20T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-26T00:00:00","2022-03-27T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-02T00:00:00"],"y":[1,1,1,1,1,1,2,1,1,1,3,6,6,6,7,5,5,6,8,8,10,17,12,100,74,64,59,52,45,39,34,32,27,25,24,20,19,18,16,15,16,15,14,13,12,11,11,11,11,10,9,10,9,9,8,8,8,7,6,6,6],"type":"scatter"},{"mode":"lines+markers","name":"War","x":["2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-05T00:00:00","2022-02-06T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-12T00:00:00","2022-02-13T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-19T00:00:00","2022-02-20T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-26T00:00:00","2022-02-27T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-05T00:00:00","2022-03-06T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-12T00:00:00","2022-03-13T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-19T00:00:00","2022-03-20T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-26T00:00:00","2022-03-27T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-02T00:00:00"],"y":[3,3,3,3,3,3,3,3,3,3,3,3,4,3,4,3,3,3,4,4,4,5,4,19,14,12,11,10,9,8,8,7,7,7,7,6,6,5,5,5,6,5,5,5,5,4,5,5,5,4,4,5,4,4,5,4,4,4,4,4,4],"type":"scatter"},{"line":{"color":"yellow"},"mode":"lines+markers","name":"Russia","x":["2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-05T00:00:00","2022-02-06T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-12T00:00:00","2022-02-13T00:00:00","2022-02- ...

# %%
by_region = pytrends.interest_by_region(resolution='COUNTRY', inc_low_vol=True, inc_geo_code=True)

by_region
# Out:
#                geoCode  war  ukraine  russia
# geoName
# Afghanistan         AF   27       37      36
# Albania             AL   18       53      29
# Algeria             DZ   24       63      13
# American Samoa      AS   39       38      23
# Andorra             AD   19       47      34
# ...                ...  ...      ...     ...
# Western Sahara      EH   24       54      22
# Yemen               YE   43       33      24
# Zambia              ZM   22       41      37
# Zimbabwe            ZW   19       44      37
# Åland Islands       AX   23       42      35
#
# [250 rows x 4 columns]

# %%
df = by_region.reset_index()

# %%
def iso_mapper(iso2):
    cntr = pycountry.countries.get(alpha_2=iso2)
    if cntr is None:
        return None
    return cntr.alpha_3

def flag_mapper(iso2):
    cntr = pycountry.countries.get(alpha_2=iso2)
    if cntr is None:
        return None
    return cntr.flag

# %%
df['iso3'] = df['geoCode'].apply(iso_mapper)
df['flag'] = df['geoCode'].apply(flag_mapper)
df
# Out:
#             geoName geoCode  war  ukraine  russia iso3 flag
# 0       Afghanistan      AF   27       37      36  AFG   🇦🇫
# 1           Albania      AL   18       53      29  ALB   🇦🇱
# 2           Algeria      DZ   24       63      13  DZA   🇩🇿
# 3    American Samoa      AS   39       38      23  ASM   🇦🇸
# 4           Andorra      AD   19       47      34  AND   🇦🇩
# ..              ...     ...  ...      ...     ...  ...  ...
# 245  Western Sahara      EH   24       54      22  ESH   🇪🇭
# 246           Yemen      YE   43       33      24  YEM   🇾🇪
# 247          Zambia      ZM   22       41      37  ZMB   🇿🇲
# 248        Zimbabwe      ZW   19       44      37  ZWE   🇿🇼
# 249   Åland Islands      AX   23       42      35  ALA   🇦🇽
#
# [250 rows x 7 columns]

# %%
fig = px.scatter_geo(df, locations='iso3', color='geoName',
                     hover_name='geoName', size='ukraine',
                     projection='orthographic', text='flag')
# fig.add_traces(
#     list(px.scatter_geo(df, locations='iso3', color='geoName',
#                      hover_name='geoName', size='war',
#                      projection='orthographic', text='flag').select_traces())
# )
fig.show()
# Out:
# <div>                            <div id="4760034f-687c-4bec-b3e7-ff9d77419c66" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4760034f-687c-4bec-b3e7-ff9d77419c66")) {                    Plotly.newPlot(                        "4760034f-687c-4bec-b3e7-ff9d77419c66",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>geoName=Afghanistan<br>ukraine=%{marker.size}<br>flag=%{text}<br>iso3=%{location}<extra></extra>","hovertext":["Afghanistan"],"legendgroup":"Afghanistan","locations":["AFG"],"marker":{"color":"#636efa","size":[37],"sizemode":"area","sizeref":0.245,"symbol":"circle"},"mode":"markers+text","name":"Afghanistan","showlegend":true,"text":["\ud83c\udde6\ud83c\uddeb"],"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>geoName=Albania<br>ukraine=%{marker.size}<br>flag=%{text}<br>iso3=%{location}<extra></extra>","hovertext":["Albania"],"legendgroup":"Albania","locations":["ALB"],"marker":{"color":"#EF553B","size":[53],"sizemode":"area","sizeref":0.245,"symbol":"circle"},"mode":"markers+text","name":"Albania","showlegend":true,"text":["\ud83c\udde6\ud83c\uddf1"],"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>geoName=Algeria<br>ukraine=%{marker.size}<br>flag=%{text}<br>iso3=%{location}<extra></extra>","hovertext":["Algeria"],"legendgroup":"Algeria","locations":["DZA"],"marker":{"color":"#00cc96","size":[63],"sizemode":"area","sizeref":0.245,"symbol":"circle"},"mode":"markers+text","name":"Algeria","showlegend":true,"text":["\ud83c\udde9\ud83c\uddff"],"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>geoName=American Samoa<br>ukraine=%{marker.size}<br>flag=%{text}<br>iso3=%{location}<extra></extra>","hovertext":["American Samoa"],"legendgroup":"American Samoa","locations":["ASM"],"marker":{"color":"#ab63fa","size":[38],"sizemode":"area","sizeref":0.245,"symbol":"circle"},"mode":"markers+text","name":"American Samoa","showlegend":true,"text":["\ud83c\udde6\ud83c\uddf8"],"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>geoName=Andorra<br>ukraine=%{marker.size}<br>flag=%{text}<br>iso3=%{location}<extra></extra>","hovertext":["Andorra"],"legendgroup":"Andorra","locations":["AND"],"marker":{"color":"#FFA15A","size":[47],"sizemode":"area","sizeref":0.245,"symbol":"circle"},"mode":"markers+text","name":"Andorra","showlegend":true,"text":["\ud83c\udde6\ud83c\udde9"],"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>geoName=Angola<br>ukraine=%{marker.size}<br>flag=%{text}<br>iso3=%{location}<extra></extra>","hovertext":["Angola"],"legendgroup":"Angola","locations":["AGO"],"marker":{"color":"#19d3f3","size":[11],"sizemode":"area","sizeref":0.245,"symbol":"circle"},"mode":"markers+text","name":"Angola","showlegend":true,"text":["\ud83c\udde6\ud83c\uddf4"],"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>geoName=Anguilla<br>ukraine=%{marker.size}<br>flag=%{text}<br>iso3=%{location}<extra></extra>","hovertext":["Anguilla"],"legendgroup":"Anguilla","locations":["AIA"],"marker":{"color":"#FF6692","size":[42],"sizemode":"area","sizeref":0.245,"symbol":"circle"},"mode":"markers+text","name":"Anguilla","showlegend":true,"text":["\ud83c\udde6\ud83c\uddee"],"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>geoName=Antarctica<br>ukraine=%{marker.size}<br>flag=%{text}<br>iso3=%{location}<extra></extra>","hovertext":["Antarctica"],"legendgroup":"Antarctica","locations":["ATA"],"marker":{"color":"#B6E880","size":[0],"sizemode":"area","sizeref":0.245,"symbol":"circle"},"mode":"markers+text","name":"Antarctica","showlegend":true,"text":["\ud83c\udde6\ud83c\uddf6"],"type":"scattergeo"},{"geo" ...

# %%
df.sort_values(['ukraine'])[-20:]
# Out:
#                       geoName geoCode  war  ukraine  russia iso3 flag
# 93                     Guinea      GN    5       87       8  GIN   🇬🇳
# 83                    Germany      DE   10       87       3  DEU   🇩🇪
# 96                      Haiti      HT    7       87       6  HTI   🇭🇹
# 59              Côte d’Ivoire      CI    6       88       6  CIV   🇨🇮
# 51           Congo - Kinshasa      CD    5       88       7  COD   🇨🇩
# 50        Congo - Brazzaville      CG    6       89       5  COG   🇨🇬
# 78           French Polynesia      PF    8       89       3  PYF   🇵🇫
# 34               Burkina Faso      BF    5       89       6  BFA   🇧🇫
# 43                       Chad      TD    4       90       6  TCD   🇹🇩
# 49                    Comoros      KM    0       92       8  COM   🇰🇲
# 89                 Guadeloupe      GP    7       92       1  GLP   🇬🇵
# 76                     France      FR    6       92       2  FRA   🇫🇷
# 137                Martinique      MQ    7       92       1  MTQ   🇲🇶
# 77              French Guiana      GF    5       93       2  GUF   🇬🇫
# 183                   Réunion      RE    5       93       2  REU   🇷🇪
# 203            St. Barthélemy      BL    7       93       0  BLM   🇧🇱
# 208     St. Pierre & Miquelon      PM    6       94       0  SPM   🇵🇲
# 155             New Caledonia      NC    6       94       0  NCL   🇳🇨
# 42   Central African Republic      CF    1       96       3  CAF   🇨🇫
# 140                   Mayotte      YT    2       98       0  MYT   🇾🇹

# %%
fig = px.bar(df.sort_values(['ukraine'])[-50:], 
             color='geoName', 
             x='geoName', 
             y='ukraine', 
             title='Top 50 Interested Countries', 
             text='flag')
fig.show()
# Out:
# <div>                            <div id="99edcc7d-2048-43aa-a6cf-d1c62b6df02b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99edcc7d-2048-43aa-a6cf-d1c62b6df02b")) {                    Plotly.newPlot(                        "99edcc7d-2048-43aa-a6cf-d1c62b6df02b",                        [{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Rwanda","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Rwanda","offsetgroup":"Rwanda","orientation":"v","showlegend":true,"text":["\ud83c\uddf7\ud83c\uddfc"],"textposition":"auto","x":["Rwanda"],"xaxis":"x","y":[53],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Canada","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"v","showlegend":true,"text":["\ud83c\udde8\ud83c\udde6"],"textposition":"auto","x":["Canada"],"xaxis":"x","y":[54],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Samoa","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Samoa","offsetgroup":"Samoa","orientation":"v","showlegend":true,"text":["\ud83c\uddfc\ud83c\uddf8"],"textposition":"auto","x":["Samoa"],"xaxis":"x","y":[54],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Western Sahara","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Western Sahara","offsetgroup":"Western Sahara","orientation":"v","showlegend":true,"text":["\ud83c\uddea\ud83c\udded"],"textposition":"auto","x":["Western Sahara"],"xaxis":"x","y":[54],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Kosovo","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Kosovo","offsetgroup":"Kosovo","orientation":"v","showlegend":true,"text":[null],"textposition":"auto","x":["Kosovo"],"xaxis":"x","y":[55],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Faroe Islands","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Faroe Islands","offsetgroup":"Faroe Islands","orientation":"v","showlegend":true,"text":["\ud83c\uddeb\ud83c\uddf4"],"textposition":"auto","x":["Faroe Islands"],"xaxis":"x","y":[60],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Ukraine","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Ukraine","offsetgroup":"Ukraine","orientation":"v","showlegend":true,"text":["\ud83c\uddfa\ud83c\udde6"],"textposition":"auto","x":["Ukraine"],"xaxis":"x","y":[63],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Algeria","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Algeria","offsetgroup":"Algeria","orientation":"v","showlegend":true,"text":["\ud83c\udde9\ud83c\uddff"],"textposition":"auto","x":["Algeria"],"xaxis":"x","y":[63],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Tunisia","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Tunisia","offsetgroup":"Tunisia","orientation":"v","showlegend":true,"text":["\ud83c\uddf9\ud83c\uddf3"],"textposition":"auto","x":["Tunisia"],"xaxis":"x","y":[64],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine= ...

# %%
related_data = pytrends.related_queries()

# %%
related_data['ukraine']['top']
# Out:
#                    query  value
# 0         russia ukraine    100
# 1                 russia    100
# 2           ukraine news     85
# 3            war ukraine     28
# 4    news russia ukraine     25
# 5            russia news     25
# 6        russian ukraine     15
# 7         ukraine russie     15
# 8                 russie     15
# 9     russia ukraine war     14
# 10    russia and ukraine     14
# 11                 putin     13
# 12         putin ukraine     13
# 13           ukraine map     11
# 14      russland ukraine     11
# 15              russland     11
# 16          live ukraine     10
# 17      ukraine konflikt      9
# 18        ukraine latest      9
# 19        guerre ukraine      9
# 20         krieg ukraine      8
# 21          ukraine nato      7
# 22                  nato      7
# 23   ukraine latest news      7
# 24  russia ukraine putin      7

# %%
related_data['war']['top']
# Out:
#                        query  value
# 0                    the war    100
# 1                ukraine war     77
# 2                     russia     58
# 3                 russia war     58
# 4                  world war     51
# 5         war ukraine russia     38
# 6             russia ukraine     38
# 7                 god of war     29
# 8                  civil war     21
# 9                   cold war     16
# 10                  war news     16
# 11            war in ukraine     15
# 12               russian war     13
# 13               world war 2     12
# 14               world war 3     10
# 15                 total war      9
# 16          ukraine war news      9
# 17    russia and ukraine war      8
# 18       ukraine russian war      8
# 19                   war map      8
# 20                 war movie      8
# 21  putin russia ukraine war      8
# 22           war with russia      8
# 23            vladimir putin      8
# 24               world war 1      7

# %%
related_data['russia']['top']
# Out:
#                    query  value
# 0         russia ukraine    100
# 1                ukraine    100
# 2            russia news     36
# 3    russia ukraine news     25
# 4           ukraine news     25
# 5                    war     22
# 6             russia war     21
# 7            ukraine war     14
# 8     russia ukraine war     14
# 9     russia and ukraine     14
# 10        russia ucraina     13
# 11               ucraina     13
# 12          putin russia     12
# 13                 putin     11
# 14        russia ucrania     10
# 15               ucrania     10
# 16                guerra      8
# 17         guerra russia      8
# 18             us russia      7
# 19  russia ukraine putin      7
# 20            russia map      6
# 21                 china      6
# 22          china russia      6
# 23                  nato      5
# 24          russia today      5

# %%
fig = px.bar(related_data['ukraine']['top'], x='query', y='value', title='Related queries')
fig.show()
# Out:
# <div>                            <div id="db66efcd-d674-40bc-8aba-9c71c7c1df27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db66efcd-d674-40bc-8aba-9c71c7c1df27")) {                    Plotly.newPlot(                        "db66efcd-d674-40bc-8aba-9c71c7c1df27",                        [{"alignmentgroup":"True","hovertemplate":"query=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["russia ukraine","russia","ukraine news","war ukraine","news russia ukraine","russia news","russian ukraine","ukraine russie","russie","russia ukraine war","russia and ukraine","putin","putin ukraine","ukraine map","russland ukraine","russland","live ukraine","ukraine konflikt","ukraine latest","guerre ukraine","krieg ukraine","ukraine nato","nato","ukraine latest news","russia ukraine putin"],"xaxis":"x","y":[100,100,85,28,25,25,15,15,15,14,14,13,13,11,11,11,10,9,9,9,8,7,7,7,7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a" ...

# %%
fig = px.bar(related_data['war']['top'], x='query', y='value', title='Related queries')
fig.show()
# Out:
# <div>                            <div id="3753b040-80f8-4f80-862e-d225709f08ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3753b040-80f8-4f80-862e-d225709f08ff")) {                    Plotly.newPlot(                        "3753b040-80f8-4f80-862e-d225709f08ff",                        [{"alignmentgroup":"True","hovertemplate":"query=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["the war","ukraine war","russia","russia war","world war","war ukraine russia","russia ukraine","god of war","civil war","cold war","war news","war in ukraine","russian war","world war 2","world war 3","total war","ukraine war news","russia and ukraine war","ukraine russian war","war map","war movie","putin russia ukraine war","war with russia","vladimir putin","world war 1"],"xaxis":"x","y":[100,77,58,58,51,38,38,29,21,16,16,15,13,12,10,9,9,8,8,8,8,8,8,8,7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888 ...
