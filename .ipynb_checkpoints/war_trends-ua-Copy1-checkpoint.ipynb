# %%
from pytrends.request import TrendReq
import pytrends as pt
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import pycountry
import plotly.graph_objects as go

# %%
pytrends = TrendReq(hl='ua', tz=360)

kw_list = ['війна', 'україна', 'росія'] # list of keywords to get data 

pytrends.build_payload(kw_list, cat=0, timeframe='today 3-m')

# %%
#1 Interest over Time

data = pytrends.interest_over_time() 
data = data.reset_index()

# %%
data = data[data['date'] >= '2022-02-01']

# %%
data = data.rename({'україна': 'ukraine', 'росія': 'russia', 'війна': 'war'}, axis=1)
data
# Out:
#          date  war  ukraine  russia  isPartial
# 27 2022-02-01    3       21       6      False
# 28 2022-02-02    5       22       4      False
# 29 2022-02-03    4       23       5      False
# 30 2022-02-04    4       52      35      False
# 31 2022-02-05    3       24       7      False
# ..        ...  ...      ...     ...        ...
# 84 2022-03-30   14       29       3      False
# 85 2022-03-31   14       28       3      False
# 86 2022-04-01   14       26       2      False
# 87 2022-04-02   15       29       2      False
# 88 2022-04-03    0        0       0       True
#
# [62 rows x 5 columns]

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=data['date'], y=data['ukraine'],
                    mode='lines+markers',
                    name='Україна'))
fig.add_trace(go.Scatter(x=data['date'], y=data['war'],
                    mode='lines+markers',
                    name='Війна'))
fig.add_trace(go.Scatter(x=data['date'], y=data['russia'],
                    mode='lines+markers', 
                    name='Росія', line_color='yellow'))

fig.show()
# Out:
# <div>                            <div id="ad50bd2c-1c2a-4ce1-809b-40da8e8f8dd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad50bd2c-1c2a-4ce1-809b-40da8e8f8dd7")) {                    Plotly.newPlot(                        "ad50bd2c-1c2a-4ce1-809b-40da8e8f8dd7",                        [{"mode":"lines+markers","name":"\u0423\u043a\u0440\u0430\u0457\u043d\u0430","x":["2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-05T00:00:00","2022-02-06T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-12T00:00:00","2022-02-13T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-19T00:00:00","2022-02-20T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-26T00:00:00","2022-02-27T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-05T00:00:00","2022-03-06T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-12T00:00:00","2022-03-13T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-19T00:00:00","2022-03-20T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-26T00:00:00","2022-03-27T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-02T00:00:00","2022-04-03T00:00:00"],"y":[21,22,23,52,24,26,23,21,20,19,21,24,27,24,28,34,26,25,27,26,31,36,40,100,71,55,48,45,44,40,37,33,31,32,28,27,25,25,31,27,30,41,34,29,30,32,30,27,30,26,26,27,30,28,34,25,28,29,28,26,29,0],"type":"scatter"},{"mode":"lines+markers","name":"\u0412\u0456\u0439\u043d\u0430","x":["2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-05T00:00:00","2022-02-06T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-12T00:00:00","2022-02-13T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-19T00:00:00","2022-02-20T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-26T00:00:00","2022-02-27T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-05T00:00:00","2022-03-06T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-12T00:00:00","2022-03-13T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-19T00:00:00","2022-03-20T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-26T00:00:00","2022-03-27T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-02T00:00:00","2022-04-03T00:00:00"],"y":[3,5,4,4,3,2,4,5,4,4,5,9,15,21,21,13,7,7,9,9,14,18,15,87,53,36,30,27,28,26,24,30,24,25,21,20,21,20,22,21,23,17,18,17,19,24,25,20,17,18,16,17,16,17,18,14,14,14,14,14,15,0],"type":"scatter"},{"line":{"color":"yellow"},"mode":"lines+markers","name":"\u0420\u043e\u0441\u0456\u044f","x":["2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","20 ...

# %%
by_region = pytrends.interest_by_region(resolution='COUNTRY', inc_low_vol=True, inc_geo_code=True)
by_region
# Out:
#                geoCode  війна  україна  росія
# geoName
# Afghanistan         AF      0        0      0
# Albania             AL      0      100      0
# Algeria             DZ      0        0      0
# American Samoa      AS      0        0      0
# Andorra             AD      0        0      0
# ...                ...    ...      ...    ...
# Western Sahara      EH      0        0      0
# Yemen               YE      0        0      0
# Zambia              ZM      0        0      0
# Zimbabwe            ZW      0        0      0
# Åland Islands       AX      0        0      0
#
# [250 rows x 4 columns]

# %%
df = by_region.reset_index()
df = df.rename({'україна': 'ukraine', 'росія': 'russia', 'війна': 'war'}, axis=1)
df
# Out:
#             geoName geoCode  war  ukraine  russia
# 0       Afghanistan      AF    0        0       0
# 1           Albania      AL    0      100       0
# 2           Algeria      DZ    0        0       0
# 3    American Samoa      AS    0        0       0
# 4           Andorra      AD    0        0       0
# ..              ...     ...  ...      ...     ...
# 245  Western Sahara      EH    0        0       0
# 246           Yemen      YE    0        0       0
# 247          Zambia      ZM    0        0       0
# 248        Zimbabwe      ZW    0        0       0
# 249   Åland Islands      AX    0        0       0
#
# [250 rows x 5 columns]

# %%
def iso_mapper(iso2):
    cntr = pycountry.countries.get(alpha_2=iso2)
    if cntr is None:
        return None
    return cntr.alpha_3

def flag_mapper(iso2):
    cntr = pycountry.countries.get(alpha_2=iso2)
    if cntr is None:
        return None
    return cntr.flag

# %%
df['iso3'] = df['geoCode'].apply(iso_mapper)
df['flag'] = df['geoCode'].apply(flag_mapper)
df
# Out:
#             geoName geoCode  war  ukraine  russia iso3 flag
# 0       Afghanistan      AF    0        0       0  AFG   🇦🇫
# 1           Albania      AL    0      100       0  ALB   🇦🇱
# 2           Algeria      DZ    0        0       0  DZA   🇩🇿
# 3    American Samoa      AS    0        0       0  ASM   🇦🇸
# 4           Andorra      AD    0        0       0  AND   🇦🇩
# ..              ...     ...  ...      ...     ...  ...  ...
# 245  Western Sahara      EH    0        0       0  ESH   🇪🇭
# 246           Yemen      YE    0        0       0  YEM   🇾🇪
# 247          Zambia      ZM    0        0       0  ZMB   🇿🇲
# 248        Zimbabwe      ZW    0        0       0  ZWE   🇿🇼
# 249   Åland Islands      AX    0        0       0  ALA   🇦🇽
#
# [250 rows x 7 columns]

# %%
fig = px.scatter_geo(df, locations='iso3', color='geoName',
                     hover_name='geoName', size='ukraine',
                     projection='orthographic', text='flag')
# fig.add_traces(
#     list(px.scatter_geo(df, locations='iso3', color='geoName',
#                      hover_name='geoName', size='war',
#                      projection='orthographic', text='flag').select_traces())
# )
fig.show()
# Out:
# <div>                            <div id="960b00ad-add5-47e2-8526-23e1ea2ff18c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("960b00ad-add5-47e2-8526-23e1ea2ff18c")) {                    Plotly.newPlot(                        "960b00ad-add5-47e2-8526-23e1ea2ff18c",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>geoName=Afghanistan<br>ukraine=%{marker.size}<br>flag=%{text}<br>iso3=%{location}<extra></extra>","hovertext":["Afghanistan"],"legendgroup":"Afghanistan","locations":["AFG"],"marker":{"color":"#636efa","size":[0],"sizemode":"area","sizeref":0.25,"symbol":"circle"},"mode":"markers+text","name":"Afghanistan","showlegend":true,"text":["\ud83c\udde6\ud83c\uddeb"],"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>geoName=Albania<br>ukraine=%{marker.size}<br>flag=%{text}<br>iso3=%{location}<extra></extra>","hovertext":["Albania"],"legendgroup":"Albania","locations":["ALB"],"marker":{"color":"#EF553B","size":[100],"sizemode":"area","sizeref":0.25,"symbol":"circle"},"mode":"markers+text","name":"Albania","showlegend":true,"text":["\ud83c\udde6\ud83c\uddf1"],"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>geoName=Algeria<br>ukraine=%{marker.size}<br>flag=%{text}<br>iso3=%{location}<extra></extra>","hovertext":["Algeria"],"legendgroup":"Algeria","locations":["DZA"],"marker":{"color":"#00cc96","size":[0],"sizemode":"area","sizeref":0.25,"symbol":"circle"},"mode":"markers+text","name":"Algeria","showlegend":true,"text":["\ud83c\udde9\ud83c\uddff"],"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>geoName=American Samoa<br>ukraine=%{marker.size}<br>flag=%{text}<br>iso3=%{location}<extra></extra>","hovertext":["American Samoa"],"legendgroup":"American Samoa","locations":["ASM"],"marker":{"color":"#ab63fa","size":[0],"sizemode":"area","sizeref":0.25,"symbol":"circle"},"mode":"markers+text","name":"American Samoa","showlegend":true,"text":["\ud83c\udde6\ud83c\uddf8"],"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>geoName=Andorra<br>ukraine=%{marker.size}<br>flag=%{text}<br>iso3=%{location}<extra></extra>","hovertext":["Andorra"],"legendgroup":"Andorra","locations":["AND"],"marker":{"color":"#FFA15A","size":[0],"sizemode":"area","sizeref":0.25,"symbol":"circle"},"mode":"markers+text","name":"Andorra","showlegend":true,"text":["\ud83c\udde6\ud83c\udde9"],"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>geoName=Angola<br>ukraine=%{marker.size}<br>flag=%{text}<br>iso3=%{location}<extra></extra>","hovertext":["Angola"],"legendgroup":"Angola","locations":["AGO"],"marker":{"color":"#19d3f3","size":[0],"sizemode":"area","sizeref":0.25,"symbol":"circle"},"mode":"markers+text","name":"Angola","showlegend":true,"text":["\ud83c\udde6\ud83c\uddf4"],"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>geoName=Anguilla<br>ukraine=%{marker.size}<br>flag=%{text}<br>iso3=%{location}<extra></extra>","hovertext":["Anguilla"],"legendgroup":"Anguilla","locations":["AIA"],"marker":{"color":"#FF6692","size":[0],"sizemode":"area","sizeref":0.25,"symbol":"circle"},"mode":"markers+text","name":"Anguilla","showlegend":true,"text":["\ud83c\udde6\ud83c\uddee"],"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>geoName=Antarctica<br>ukraine=%{marker.size}<br>flag=%{text}<br>iso3=%{location}<extra></extra>","hovertext":["Antarctica"],"legendgroup":"Antarctica","locations":["ATA"],"marker":{"color":"#B6E880","size":[0],"sizemode":"area","sizeref":0.25,"symbol":"circle"},"mode":"markers+text","name":"Antarctica","showlegend":true,"text":["\ud83c\udde6\ud83c\uddf6"],"type":"scattergeo"},{"geo":"geo","hover ...

# %%
df.sort_values(['ukraine'])[-20:]
# Out:
#               geoName geoCode  war  ukraine  russia iso3 flag
# 159           Nigeria      NG    0      100       0  NGA   🇳🇬
# 163   North Macedonia      MK    0      100       0  MKD   🇲🇰
# 167          Pakistan      PK    0      100       0  PAK   🇵🇰
# 51   Congo - Kinshasa      CD    0      100       0  COD   🇨🇩
# 132          Malaysia      MY    0      100       0  MYS   🇲🇾
# 48           Colombia      CO    0      100       0  COL   🇨🇴
# 217            Taiwan      TW    0      100       0  TWN   🇹🇼
# 174       Philippines      PH    0      100       0  PHL   🇵🇭
# 179             Qatar      QA    0      100       0  QAT   🇶🇦
# 45              China      CN    0      100       0  CHN   🇨🇳
# 44              Chile      CL    0      100       0  CHL   🇨🇱
# 186      Saudi Arabia      SA    0      100       0  SAU   🇸🇦
# 188            Serbia      RS    0      100       0  SRB   🇷🇸
# 191         Singapore      SG    0      100       0  SGP   🇸🇬
# 119        Kyrgyzstan      KG    0      100       0  KGZ   🇰🇬
# 202         Sri Lanka      LK    0      100       0  LKA   🇱🇰
# 115             Kenya      KE    0      100       0  KEN   🇰🇪
# 113            Jordan      JO    0      100       0  JOR   🇯🇴
# 128        Luxembourg      LU    0      100       0  LUX   🇱🇺
# 173              Peru      PE    0      100       0  PER   🇵🇪

# %%
fig = px.bar(df.sort_values(['ukraine'])[-50:], 
             color='geoName', 
             x='geoName', 
             y='ukraine', 
             title='Top 50 Interested Countries (Україна)', 
             text='flag')
fig.show()
# Out:
# <div>                            <div id="e0a54f19-d436-4426-9b96-1a6c43802aa8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0a54f19-d436-4426-9b96-1a6c43802aa8")) {                    Plotly.newPlot(                        "e0a54f19-d436-4426-9b96-1a6c43802aa8",                        [{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Russia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Russia","offsetgroup":"Russia","orientation":"v","showlegend":true,"text":["\ud83c\uddf7\ud83c\uddfa"],"textposition":"auto","x":["Russia"],"xaxis":"x","y":[76],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Lithuania","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Lithuania","offsetgroup":"Lithuania","orientation":"v","showlegend":true,"text":["\ud83c\uddf1\ud83c\uddf9"],"textposition":"auto","x":["Lithuania"],"xaxis":"x","y":[76],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Bulgaria","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bulgaria","offsetgroup":"Bulgaria","orientation":"v","showlegend":true,"text":["\ud83c\udde7\ud83c\uddec"],"textposition":"auto","x":["Bulgaria"],"xaxis":"x","y":[77],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Azerbaijan","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Azerbaijan","offsetgroup":"Azerbaijan","orientation":"v","showlegend":true,"text":["\ud83c\udde6\ud83c\uddff"],"textposition":"auto","x":["Azerbaijan"],"xaxis":"x","y":[78],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Brazil","offsetgroup":"Brazil","orientation":"v","showlegend":true,"text":["\ud83c\udde7\ud83c\uddf7"],"textposition":"auto","x":["Brazil"],"xaxis":"x","y":[79],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"India","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"text":["\ud83c\uddee\ud83c\uddf3"],"textposition":"auto","x":["India"],"xaxis":"x","y":[79],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Belarus","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Belarus","offsetgroup":"Belarus","orientation":"v","showlegend":true,"text":["\ud83c\udde7\ud83c\uddfe"],"textposition":"auto","x":["Belarus"],"xaxis":"x","y":[80],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Ireland","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Ireland","offsetgroup":"Ireland","orientation":"v","showlegend":true,"text":["\ud83c\uddee\ud83c\uddea"],"textposition":"auto","x":["Ireland"],"xaxis":"x","y":[80],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<br>flag=%{text}<extra></extra>","legendgroup":"Cyprus","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Cyprus","offsetgroup":"Cyprus","orientation":"v","showlegend":true,"text":["\ud83c\udde8\ud83c\uddfe"],"textposition":"auto","x":["Cyprus"],"xaxis":"x","y":[82],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"geoName=%{x}<br>ukraine=%{y}<b ...

# %%
related_data = pytrends.related_queries()

# %%
fig = px.bar(related_data['україна']['top'], x='query', y='value', title='Related queries')
fig.show()
# Out:
# <div>                            <div id="af09e607-5da3-45f6-be21-cc82c505e830" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af09e607-5da3-45f6-be21-cc82c505e830")) {                    Plotly.newPlot(                        "af09e607-5da3-45f6-be21-cc82c505e830",                        [{"alignmentgroup":"True","hovertemplate":"query=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\u0443\u043a\u0440\u0430\u0457\u043d\u0430 \u043d\u043e\u0432\u0438\u043d\u0438","\u043d\u043e\u0432\u0438\u043d\u0438","\u0443\u043a\u0440\u0430\u0457\u043d\u0430 24","\u0443\u043a\u0440\u0430\u0457\u043d\u0430 \u043e\u043d\u043b\u0430\u0439\u043d","\u0443\u043a\u0440\u0430\u0457\u043d\u0430 \u0440\u043e\u0441\u0456\u044f","\u0440\u043e\u0441\u0456\u044f","24 \u0443\u043a\u0440\u0430\u0457\u043d\u0430 \u043e\u043d\u043b\u0430\u0439\u043d","\u0443\u043a\u0440\u0430\u0457\u043d\u0430 \u0441\u044c\u043e\u0433\u043e\u0434\u043d\u0456","\u043f\u0440\u043e\u0433\u0440\u0430\u043c\u0430 \u0443\u043a\u0440\u0430\u0457\u043d\u0430","\u0443\u043a\u0440\u0430\u0438\u043d\u0430","\u043a\u0430\u0440\u0442\u0430","\u0443\u043a\u0440\u0430\u0457\u043d\u0430 \u043a\u0430\u0440\u0442\u0430","\u0443\u043a\u0440\u0430\u0457\u043d\u0430 \u0432\u0456\u0439\u043d\u0430","\u0443\u043a\u0440\u0430\u0457\u043d\u0430 \u0446\u0435","\u043a\u0430\u043d\u0430\u043b \u0443\u043a\u0440\u0430\u0457\u043d\u0430","\u0433\u043e\u0432\u043e\u0440\u0438\u0442\u044c \u0443\u043a\u0440\u0430\u0457\u043d\u0430","\u043f\u0440\u044f\u043c\u0438\u0439 \u0435\u0444\u0456\u0440 \u0443\u043a\u0440\u0430\u0457\u043d\u0430","\u043f\u043e\u0433\u043e\u0434\u0430 \u0443\u043a\u0440\u0430\u0457\u043d\u0430","\u0443\u043a\u0440\u0430\u0457\u043d\u0430 \u0441\u044c\u043e\u0433\u043e\u0434\u043d\u0456 \u043d\u043e\u0432\u0438\u043d\u0438","\u044e\u0442\u0443\u0431 \u0443\u043a\u0440\u0430\u0457\u043d\u0430","\u043d\u043e\u0432\u0438\u043d\u0438 24","\u0440\u0431\u043a \u0443\u043a\u0440\u0430\u0457\u043d\u0430","\u0443\u043a\u0440\u0430\u0457\u043d\u0430 24 \u043d\u043e\u0432\u0438\u043d\u0438","\u043d\u043e\u0432\u0438\u043d\u0438 \u0443\u043a\u0440\u0430\u0457\u043d\u0430 24","\u0442\u0440\u043a \u0443\u043a\u0440\u0430\u0457\u043d\u0430"],"xaxis":"x","y":[100,100,72,55,31,31,27,25,24,23,19,19,16,13,12,9,9,8,8,6,6,6,6,6,5],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111, ...

# %%
fig = px.bar(related_data['війна']['top'], x='query', y='value', title='Related queries')
fig.show()
# Out:
# <div>                            <div id="3b4449ac-ebf4-4306-9466-c37907f9eb33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b4449ac-ebf4-4306-9466-c37907f9eb33")) {                    Plotly.newPlot(                        "3b4449ac-ebf4-4306-9466-c37907f9eb33",                        [{"alignmentgroup":"True","hovertemplate":"query=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\u043d\u043e\u0432\u0438\u043d\u0438","\u043d\u043e\u0432\u0438\u043d\u0438 \u0432\u0456\u0439\u043d\u0430","\u0432\u0456\u0439\u043d\u0430 \u0432 \u0443\u043a\u0440\u0430\u0457\u043d\u0456","\u043d\u043e\u0432\u0438\u043d\u0438 \u0443\u043a\u0440\u0430\u0457\u043d\u0438 \u0432\u0456\u0439\u043d\u0430","\u043d\u043e\u0432\u0438\u043d\u0438 \u0443\u043a\u0440\u0430\u0457\u043d\u0438","\u0432\u0456\u0439\u043d\u0430 2022","\u0432\u0456\u0439\u043d\u0430 \u0432 \u0443\u043a\u0440\u0430\u0457\u043d\u0456 2022","\u043a\u043e\u043b\u0438 \u0437\u0430\u043a\u0456\u043d\u0447\u0438\u0442\u044c\u0441\u044f \u0432\u0456\u0439\u043d\u0430","\u0432\u0456\u0439\u043d\u0430 \u043e\u0441\u0442\u0430\u043d\u043d\u0456 \u043d\u043e\u0432\u0438\u043d\u0438","\u043e\u0441\u0442\u0430\u043d\u043d\u0456 \u043d\u043e\u0432\u0438\u043d\u0438","\u043d\u043e\u0432\u0438\u043d\u0438 \u0432\u0456\u0439\u043d\u0430 \u0432 \u0443\u043a\u0440\u0430\u0457\u043d\u0456","\u0443\u043a\u0440\u0430\u0457\u043d\u0430 \u0432\u0456\u0439\u043d\u0430","\u0443\u043a\u0440\u0430\u0457\u043d\u0430","\u043a\u043e\u043b\u0438 \u0437\u0430\u043a\u0456\u043d\u0447\u0438\u0442\u044c\u0441\u044f \u0432\u0456\u0439\u043d\u0430 \u0432 \u0443\u043a\u0440\u0430\u0457\u043d\u0456","\u0431\u0443\u0434\u0435 \u0432\u0456\u0439\u043d\u0430","\u0432\u0456\u0439\u043d\u0430 \u0441\u044c\u043e\u0433\u043e\u0434\u043d\u0456","\u0432\u0456\u0439\u043d\u0430 \u0432 \u0443\u043a\u0440\u0430\u0457\u043d\u0456 \u043e\u0441\u0442\u0430\u043d\u043d\u0456 \u043d\u043e\u0432\u0438\u043d\u0438","\u043e\u0441\u0442\u0430\u043d\u043d\u0456 \u043d\u043e\u0432\u0438\u043d\u0438 \u0443\u043a\u0440\u0430\u0457\u043d\u0438 \u0432\u0456\u0439\u043d\u0430","\u043e\u0441\u0442\u0430\u043d\u043d\u0456 \u043d\u043e\u0432\u0438\u043d\u0438 \u0443\u043a\u0440\u0430\u0457\u043d\u0438","\u043d\u043e\u0432\u0438\u043d\u0438 \u0443\u043a\u0440\u0430\u0457\u043d\u0438 \u0432\u0456\u0439\u043d\u0430 \u043e\u0441\u0442\u0430\u043d\u043d\u0456 \u043d\u043e\u0432\u0438\u043d\u0438","\u0434\u0440\u0443\u0433\u0430 \u0441\u0432\u0456\u0442\u043e\u0432\u0430 \u0432\u0456\u0439\u043d\u0430","\u043a\u0430\u0440\u0442\u0430","\u0432\u0456\u0439\u043d\u0430 \u043a\u0430\u0440\u0442\u0430","\u0447\u0438 \u0431\u0443\u0434\u0435 \u0432\u0456\u0439\u043d\u0430","\u043f\u0435\u0440\u0448\u0430 \u0441\u0432\u0456\u0442\u043e\u0432\u0430"],"xaxis":"x","y":[100,100,99,53,53,53,32,30,28,28,21,17,17,16,14,14,11,10,10,10,9,8,8,7,5],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropl ...
